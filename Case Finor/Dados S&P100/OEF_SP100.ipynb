# %% [markdown]
# Comparação de ETF com Índice em Busca de Minimizar o Tracking Error

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import plotly.graph_objects as go

# %%
# Download das cotações históricas do OEF e SP100
returns = pd.DataFrame(yf.download(['^SP100','AAPL','MSFT','AMZN'],'2016-12-29',datetime.date.today()+datetime.timedelta(1))['Adj Close'])

# Cálculo da variação % diária dos ativos
returns = returns.apply(lambda x: (x / x.shift(1)-1).fillna(0))

# Cálculo do retorno acumulado para o período selecionado
returns = ((1 + returns).cumprod())*100
returns
# Out:
# [*********************100%%**********************]  4 of 4 completed
# Ticker            AAPL        AMZN        MSFT      ^SP100
# Date
# 2016-12-29  100.000000  100.000000  100.000000  100.000000
# 2016-12-30   99.220417   98.003006   98.791725   99.512192
# 2017-01-03   99.503109   98.499637   99.491269  100.432605
# 2017-01-04   99.391715   98.958378   99.046108  100.760824
# 2017-01-05   99.897186  101.999606   99.046108  100.787927
# ...                ...         ...         ...         ...
# 2024-04-12  650.898518  486.519000  735.980418  244.188954
# 2024-04-15  636.667599  479.958169  721.571356  241.026219
# 2024-04-16  624.464413  479.174041  723.211083  240.676925
# 2024-04-17  619.376659  473.841731  718.431327  239.241595
# 2024-04-18  617.680722  475.200953  714.733117  240.327632
#
# [1837 rows x 4 columns]

# %%
fig = go.Figure()

for i in returns.columns:
    fig.add_trace(go.Scatter(x=returns.index,y=returns[i],name=i))
fig.show()
