# %% [markdown]
# Comparação de ETF com Índice em Busca de Minimizar o Tracking Error

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime
import plotly.graph_objects as go

# %%
# Download das cotações históricas do IBOV e BOVA11
returns = pd.DataFrame(yf.download('^BVSP','2016-12-29',datetime.date.today()+datetime.timedelta(1))['Adj Close'])
returns['BOVA11'] = yf.download('BOVA11.SA','2016-12-29',datetime.date.today()+datetime.timedelta(1))['Adj Close']

# Cálculo da variação % diária dos ativos
returns = returns.apply(lambda x: (x / x.shift(1)-1).fillna(0))
returns.columns = ['IBOV','BOVA11']

# Cálculo do retorno acumulado para o período selecionado
returns = ((1 + returns).cumprod())*100
returns
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#                   IBOV      BOVA11
# Date
# 2016-12-29  100.000000  100.000000
# 2017-01-02   98.940674   98.952609
# 2017-01-03  102.635031  102.592717
# 2017-01-04  102.261444  102.592717
# 2017-01-05  103.061750  103.107825
# ...                ...         ...
# 2024-04-09  215.667392  222.294997
# 2024-04-10  212.618925  218.666702
# 2024-04-11  211.526392  217.909338
# 2024-04-12  209.118834  215.091244
# 2024-04-15  208.102678  214.087297
#
# [1806 rows x 2 columns]

# %%
# Criação do Gráfico

fig = go.Figure()

for i in returns.columns:
    fig.add_trace(go.Scatter(x=returns.index,y=returns[i],name=i))
fig.show()
